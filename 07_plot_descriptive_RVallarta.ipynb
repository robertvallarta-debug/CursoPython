# %%
import pandas as pd

def read_csv_to_dataframe(file_path):
    """
    Reads a comma-separated CSV file and converts it into a pandas DataFrame.
    
    Parameters:
        file_path (str): Path to the CSV file.
    
    Returns:
        pd.DataFrame: DataFrame containing the CSV data.
    """
    df = pd.read_csv(file_path)  # assumes the file is comma-separated
    return df

# %%
# Ensure the function is defined (run the cell with the function definition if needed)
tallas_sardine = pd.read_csv(
	r"C:\Respaldo ASUS Robert\Rprojects\Doctorado\analisis_datos\gloria\unidos_todos_paper.csv",
	encoding="latin1"
)
print(tallas_sardine.head())  # show first 5 rows
# Out:
#    id  viaje.x  lance.x  latitud  longitud nictemeral          haul_id  \
# 0   6     1904        6  22.9537 -106.2396          N  JCFINP/1904 _ 6
# 1   7     1904        6  22.9537 -106.2396          N  JCFINP/1904 _ 6
# 2   8     1904        6  22.9537 -106.2396          N  JCFINP/1904 _ 6
# 3   9     1904        6  22.9537 -106.2396          N  JCFINP/1904 _ 6
# 4  10     1904        6  22.9537 -106.2396          N  JCFINP/1904 _ 6
#
#              barco      viaje.y region  ...            comun  \
# 0  DR. J. CARRANZA  JCFINP/1904     GC  ...  Sardina crinuda
# 1  DR. J. CARRANZA  JCFINP/1904     GC  ...  Sardina crinuda
# 2  DR. J. CARRANZA  JCFINP/1904     GC  ...  Sardina crinuda
# 3  DR. J. CARRANZA  JCFINP/1904     GC  ...  Sardina crinuda
# 4  DR. J. CARRANZA  JCFINP/1904     GC  ...  Sardina crinuda
#
#                especie cvesp  barco.1  captura muestra ID..cont..Estomacal  \
# 0  Opisthonema bulleri     4      NaN      NaN    3.96                 NaN
# ...

# %%
import seaborn as sns

sns.set_theme(style="darkgrid")
sns.displot(
    tallas_sardine, x="patron", col="especie",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
# Ensure the function is defined (run the cell with the function definition if needed)
data_sardine = read_csv_to_dataframe(r"C:\Respaldo ASUS Robert\Rprojects\Doctorado\analisis_datos\integrados\TODAS_ESPECIES_integrado_zonas.csv")
print(data_sardine.head())  # show first 5 rows

oxy_sp = data_sardine[["especie", "Oxygen"]]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear diagrama de violín para cada nivel de "Season"
plt.figure(figsize=(8, 5))
sns.violinplot(x="especie", y="Oxygen", data=data_sardine, palette="Set2")

# Personalizar
plt.title("Tolerancia de OD por Especie")
plt.xlabel("Especie")
plt.ylabel("OD (mg/L)")

# Mostrar gráfico
plt.show()
# Out:
# C:\Users\roberto.vallarta_ina\AppData\Local\Temp\ipykernel_14044\4248890837.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="especie", y="Oxygen", data=data_sardine, palette="Set2")
